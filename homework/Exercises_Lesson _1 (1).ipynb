# %%
#You are given a list of movies with title, rating, and watched.
#Display only movies that are not watched
#Display movies with rating higher than 8
#Create a function recommend_movie(movie)

# %%
# You are given a list of products with name, price, and in_stock.
# Display only products that are in stock
# Calculate total price of all products
# Create a function apply_discount(product, percent)

# %%
#A list contains some usernames, and some of them appear more than once:
#usernames = ["ana", "mark", "john", "ana", "john", "ana"]
#Find all duplicated usernames
#Count how many times each duplicated username appears
#Display the result in a readable format

# %%
# You are given a list of coffee orders. Each order contains customer_name, coffee_type, and size.
# Display all orders in a friendly format
# Count how many large coffees were ordered
# Create a function format_order(order)

# %%
#You are given a list of attendees with name, checked_in, and ticket_type.
#Display only attendees who checked in
#Count VIP attendees
#Create a function is_vip(attendee)

# %%
#Create a function that takes a text file as input and returns the number of words contained in the text file. 
#Please take into consideration that a comma can separate some words with no space. 
#For example, "Hi, it's me." would need to be counted as three words. For your convenience, you can use the text file in the attachment.

# %%
#Write a Python Program that prints the reversed version of a string.
#The program must preserve uppercase and lowercase letters.
#If the string is empty, print it intact.

# %%
#Write a Python program that prints the string s without the character at index n.
#If the index n is out of range, print the string s intact.
#If the string s is empty, print the string s intact.
